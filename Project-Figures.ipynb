# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Path to the training dataset CSV file
csv_file_path = r"C:\Users\16395\Downloads\train_gr\train.csv"

# Read the CSV file into a Pandas DataFrame
train_data = pd.read_csv(csv_file_path)

# Display the first few rows of the training dataset
print(train_data.head())
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review  user_suggestion
# 0  I'm scared and hearing creepy voices.  So I'll...                1
# 1  Best game, more better than Sam Pepper's YouTu...                1
# 2  A littly iffy on the controls, but once you kn...                1
# 3  Great game, fun and colorful and all that.A si...                1
# 4  Not many games have the cute tag right next to...                1

# %%
import matplotlib.pyplot as plt

# Sample data (assuming the data is stored in a variable named 'train_data')
user_suggestions = train_data['user_suggestion']

# Create a histogram with two bins (0 and 1)
plt.hist(user_suggestions, bins=[-0.5, 0.5, 1.5], edgecolor='black', alpha=0.7)
plt.xlabel('User Suggestion')
plt.ylabel('Frequency')
plt.title('Distribution of User Suggestions')
plt.xticks([0, 1])  # Set x-axis ticks to be exactly at 0 and 1
plt.show()

# %%
# Display a sample of the train_data dataset
print(train_data[['user_review', 'user_suggestion']].head())
# Out:
#                                          user_review  user_suggestion
# 0  I'm scared and hearing creepy voices.  So I'll...                1
# 1  Best game, more better than Sam Pepper's YouTu...                1
# 2  A littly iffy on the controls, but once you kn...                1
# 3  Great game, fun and colorful and all that.A si...                1
# 4  Not many games have the cute tag right next to...                1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Synthetic data 
algorithms = ['KNN', 'SVM', 'Random Forest', 'Decision Tree', 'Linear Regression']
accuracy_scores = [0.85, 0.92, 0.88, 0.87, 0.75]
precision_scores = [0.88, 0.93, 0.85, 0.82, 0.78]

# Plotting the bar chart
width = 0.35  # Width of the bars
ind = np.arange(len(algorithms))  # X-axis positions

fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, accuracy_scores, width, label='Accuracy')
rects2 = ax.bar(ind + width/2, precision_scores, width, label='Precision')

# Adding labels, title, and legend
ax.set_xlabel('Algorithms')
ax.set_ylabel('Scores')
ax.set_title('Performance Comparison of Algorithms')
ax.set_xticks(ind)
ax.set_xticklabels(algorithms)
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Synthetic data 
algorithms = ['KNN', 'SVM', 'Random Forest', 'Decision Tree', 'Linear Regression']
accuracy_scores = [0.85, 0.92, 0.88, 0.87, 0.75]
precision_scores = [0.88, 0.93, 0.85, 0.82, 0.78]

# Set up figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Bar width
bar_width = 0.35

# Bar positions
bar_positions1 = np.arange(len(algorithms))
bar_positions2 = bar_positions1 + bar_width

# Plot bars
bar1 = ax.bar(bar_positions1, accuracy_scores, bar_width, label='Accuracy')
bar2 = ax.bar(bar_positions2, precision_scores, bar_width, label='Precision')

# X-axis and labels
ax.set_xticks(bar_positions1 + bar_width / 2)
ax.set_xticklabels(algorithms)
ax.set_xlabel('Algorithms')

# Y-axis
ax.set_ylabel('Scores')
ax.set_ylim(0, 1)

# Title and legend
ax.set_title('Algorithm Performance Comparison')
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
algorithms = ['KNN', 'SVM', 'Random Forest', 'Decision Tree', 'Linear Regression']
accuracy_scores = [0.75, 0.80, 0.78, 0.76, 0.70]

# Plotting
plt.bar(algorithms, accuracy_scores, color='skyblue')
plt.xlabel('Algorithms')
plt.ylabel('Accuracy Score')
plt.title('Performance Comparison of Algorithms')
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
labels = ['Recommended', 'Not Recommended']
sizes = [800, 200]

# Plotting
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['lightgreen', 'lightcoral'])
plt.title('Distribution of Samples in Dataset')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'original_samples' is the total number of samples in the original dataset
original_samples = 10000
filtered_samples = 5000  # Number of samples after filtering

# Calculate the number of samples in training and testing sets
train_samples = int(original_samples * 0.8)
test_samples = original_samples - train_samples

# Plot the dataset figure
fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(['Original Dataset', 'Filtered Dataset', 'Training Set', 'Testing Set'],
       [original_samples, filtered_samples, train_samples, test_samples],
       color=['blue', 'orange', 'green', 'red'])
ax.set_ylabel('Number of Samples')
ax.set_title('Revised Dataset Figure')
plt.show()

# %%
models = ['K-Nearest Neighbors', 'Multinomial Naive Bayes', 'Bernoulli Naive Bayes', 'Decision Tree']
accuracy_scores = [0.75, 0.73, 0.76, 0.67]
precision_scores = [0.72, 0.98, 0.92, 0.69]
recall_scores = [0.89, 0.68, 0.73, 0.76]
f1_scores = [0.80, 0.80, 0.81, 0.72]

# Plot the results figure
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.2
bar_positions = range(len(models))

ax.bar([pos - bar_width * 1.5 for pos in bar_positions], accuracy_scores, width=bar_width, label='Accuracy')
ax.bar([pos - bar_width * 0.5 for pos in bar_positions], precision_scores, width=bar_width, label='Precision')
ax.bar([pos + bar_width * 0.5 for pos in bar_positions], recall_scores, width=bar_width, label='Recall')
ax.bar([pos + bar_width * 1.5 for pos in bar_positions], f1_scores, width=bar_width, label='F1 Score')

ax.set_xticks(bar_positions)
ax.set_xticklabels(models)
ax.set_ylabel('Scores')
ax.set_title('Revised Results Figure')
ax.legend()
plt.show()
